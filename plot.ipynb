# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

x = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
t1 = [0.83261803, 0.45922747, 0.72961373, 0.71244635, 0.43776824, 0.72532189, 0.83261803, 0.72532189, 0.77253219, 0.72961373]
t2 = [0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975]
t1_MTL = [0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824, 0.43776824]
t2_MTL = [0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975, 0.43037975]
t_MTL = [0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399, 0.43407399]
plt.plot(x, t1, color='black', marker='o')
plt.plot(x, t2, color='yellow', marker='o')
# plt.plot(x, t1_MTL, color='red', marker='o')
# plt.plot(x, t2_MTL, color='green', marker='o')
# plt.plot(x, t_MTL, color='blue', marker='o')
plt.text(10, 0.72961373, 'Task 1 (not MTL)', fontsize=12)
plt.text(30, 0.43037975, 'Task 2 (not MTL)', fontsize=12)
# plt.text(20, 0.43407399, 'Multi Task', fontsize=12)
plt.xlabel('epoch')
plt.ylabel('test errors')
plt.title('no DMTL')
plt.show()

plt.plot(x, t1, color='black', marker='o')
# plt.plot(x, t2, color='yellow', marker='o')
plt.plot(x, t1_MTL, color='red', marker='o')
# plt.plot(x, t2_MTL, color='green', marker='o')
# plt.plot(x, t_MTL, color='blue', marker='o')
plt.text(10, 0.72961373, 'Task 1 (not MTL)', fontsize=12)
plt.text(30, 0.43776824, 'Task 1 in MTL', fontsize=12)
# plt.text(20, 0.43407399, 'Multi Task', fontsize=12)
plt.xlabel('epoch')
plt.ylabel('test errors')
plt.title('Task 1')
plt.show()

# plt.plot(x, t1, color='black', marker='o')
# plt.plot(x, t2, color='yellow', marker='o')
plt.plot(x, t1_MTL, color='red', marker='o')
plt.plot(x, t2_MTL, color='green', marker='o')
plt.plot(x, t_MTL, color='blue', marker='o')
plt.text(20, 0.43776824, 'Task 1 in MTL', fontsize=12)
plt.text(20, 0.43037975, 'Task 2 in MTL', fontsize=12)
plt.text(20, 0.43407399, 'Multi-Task', fontsize=12)
plt.xlabel('epoch')
plt.ylabel('test errors')
plt.title('DMTL')
plt.show()
